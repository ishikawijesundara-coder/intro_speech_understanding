# %%
import homework2
help(homework2)
# Out:
# Help on module homework2:
#
# NAME
#     homework2
#
# DESCRIPTION
#     This homework defines one method, called "arithmetic".
#     that method, type `help homework2.arithmetic`.
#
# FUNCTIONS
#     arithmetic(x, y)
#         Modify this code so that it performs one of four possible functions,
#         as specified in the following table:
#
#                             isinstance(x,str)  isinstance(x,float)
#         isinstance(y,str)   return x+y         return str(x)+y
#         isinstance(y,float) return x*int(y)    return x*y
#
# FILE
#     /Users/ishika/Downloads/intro_speech_understanding/lec02/homework2.py

# %%
import grade
# Out:
# FFFF
# ...
# FAIL: test_floatfloat (grade.Test.test_floatfloat)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/ishika/Downloads/intro_speech_understanding/lec02/grade.py", line 14, in test_floatfloat
#     self.assertAlmostEqual(homework2.arithmetic(3.0, 2.0), 6.0)
#     ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 0 != 6.0 within 7 places (6.0 difference)
#
# ...
# FAIL: test_floatstr (grade.Test.test_floatstr)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/Users/ishika/Downloads/intro_speech_understanding/lec02/grade.py", line 11, in test_floatstr
#     self.assertEqual(homework2.arithmetic(3.12, "foo"), "3.12foo")
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: 0 != '3.12foo'
#
# ...
# FAIL: test_strfloat (grade.Test.test_strfloat)
# ...

# %%
importlib.reload(grade)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 importlib.reload(grade)
#
# NameError: name 'importlib' is not defined
