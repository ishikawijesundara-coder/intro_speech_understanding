# %%
import importlib
import grade
importlib.reload(grade)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.002s
#
# OK
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.002s
#
# OK
# 4 successes out of 4 tests run
# Score: 100%
# 4 successes out of 4 tests run
# Score: 100%
# <module 'grade' from '/Users/ishika/Downloads/intro_speech_understanding/lec02/grade.py'>
