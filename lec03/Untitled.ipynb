# %%
import importlib, grade
importlib.reload(grade)
# Out:
# Traceback (most recent call last):
#
#   File /opt/anaconda3/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     import importlib, grade
#
#   File ~/Downloads/intro_speech_understanding/lec03/grade.py:1
#     import unittest, homework3
#
#   File ~/Downloads/intro_speech_understanding/lec03/homework3.py:19
#     for c instr(word):
#           ^
# SyntaxError: invalid syntax
